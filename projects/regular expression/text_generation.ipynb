# %% [markdown]
# # Conditional frequency distributions

# %% [markdown]
# ## 1. Using simple bigrams

# %% [markdown]
# ### 1.1 Download the Brown corpus

# %%
import nltk
from nltk.corpus import brown
nltk.download('brown')
# Out:
# [nltk_data] Downloading package brown to
# [nltk_data]     /Users/atsushihatakeyama/nltk_data...
# [nltk_data]   Package brown is already up-to-date!
# True

# %% [markdown]
# ### 1.2 Create a bigram model

# %%
text = brown.words(categories='news')
bigrams = nltk.bigrams(text)
cfd = nltk.ConditionalFreqDist(bigrams)

# %%
def generate_text(cfdist, word, num=50):
    for i in range(num):
        print(word, end=' ')
        word = cfdist[word].max()

# %% [markdown]
# ### 1.3 Test it
# Use a variety of different words!

# %%
# here is just one example, try some others yourself
generate_text(cfd, 'We')
# Out:
# We must be a year . The President Kennedy , and the first time . The President Kennedy , and the first time . The President Kennedy , and the first time . The President Kennedy , and the first time . The President Kennedy , and the first time

# %% [markdown]
# ## 2. Make it more generative
# Pick the next word at random from the list of bigrams

# %% [markdown]
# 1. Add a parameter for the number of bigrams to consider
# 2. Assign the bigrams for the current word to a frequency distribution
# 3. Create a list of the top N bigrams
# 4. Pick one at random and assign to the variable 'word'

# %%
# fill in the blanks marked X
import random
def generate_text(cfdist, word, num=100, X=2):   #1
    for i in range(num):
        print(word, end=' ')
        fdist = cfdist[word]                    #2
        words = list(fdist.keys())              #3
        word = random.choice(words)             #4

# %% [markdown]
# ### 2.1 Reveal the solution (only if you get stuck!)

# %%
# solution
import random
def generate_text(cfdist, word, num=100, n=2): 
    for i in range(num):
        print(word, end=' ')
        fdist = cfdist[word]
        words = list(fdist.keys())[:n]
        word = random.choice(words)

# %% [markdown]
# ## 3. Test your solution using different values of N

# %%
generate_text(cfd, 'He', n=2)
# Out:
# He told The jury had been under the City of the City of the election , which the City Executive Committee , `` no -- and the election produced extraordinary steps to have these laws `` no -- a number of the City Executive Committee . The Fulton County purchasing equipment needed for the City Executive Committee . `` no -- a number to have these laws studied at 637 E. Hughes of the election , which had been under the City Executive Committee . The Fulton County purchasing equipment needed to investigate . The jury had over-all shortage in
